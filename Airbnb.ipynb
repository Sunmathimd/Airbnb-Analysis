# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (677 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 10.1 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 29.3 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.6.1

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
pd.set_option('display.max_columns', None) #display all columns when you print a DataFrame. By setting display.max_columns to None,
#it removes the limit on the number of columns displayed, allowing you to see all columns in the DataFrame when you print it.

# %%
cloud_client = MongoClient("mongodb+srv://sunmathidharmaraja:Sunmathimd@cluster0.fn1izv0.mongodb.net/")
db = cloud_client["sample_airbnb"] #using airbnb database in mongodb
col= db["listingsAndReviews"] #collection within the database

# %%
data = []
for i in col.find( {}, {'_id': 1, 'name': 1, 'host_id': 1, 'host_name': 1, 'neighbourhood_group': 1, 'neighbourhood': 1,   #col.find({}, {...}) fetches documents from the collection
                        'latitude': 1, 'longitude': 1, 'room_type': 1, 'price': 1, 'minimum_nights': 1, 'number_of_reviews': 1,
                        'last_review': 1, 'reviews_per_month': 1, 'calculated_host_listings_count': 1, 'availability_365': 1,
                        'property_type': 1, 'room_type': 1, 'bed_type': 1,
                        'minimum_nights': 1, 'maximum_nights': 1, 'cancellation_policy': 1, 'accommodates': 1,
                        'bedrooms': 1, 'beds': 1, 'number_of_reviews': 1, 'bathrooms': 1, 'price': 1,
                        'cleaning_fee': 1, 'extra_people': 1, 'guests_included': 1, 'images.picture_url': 1,
                        'review_scores.review_scores_rating': 1} ):
    data.append(i) #to collect the results of a database

# %%
df_1 = pd.DataFrame(data)
df_1['images'] = df_1['images'].apply(lambda x: x['picture_url'])
df_1['review_scores'] = df_1['review_scores'].apply(lambda x: x.get('review_scores_rating', 0))
df_1.head()
# Out:
#         _id                                 name property_type  \
# 0   1001265     Ocean View Waikiki Marina w/prkg   Condominium
# 1   1003530  New York City - Upper West Side Apt     Apartment
# 2  10057447       Modern Spacious 1 Bedroom Loft     Apartment
# 3  10038496         Copacabana Apartment Posto 6     Apartment
# 4  10047964       Charming Flat in Downtown Moda         House
#
#          room_type  bed_type minimum_nights maximum_nights  \
# 0  Entire home/apt  Real Bed              3            365
# 1     Private room  Real Bed             12            360
# 2  Entire home/apt  Real Bed              1           1125
# 3  Entire home/apt  Real Bed              3             75
# 4  Entire home/apt  Real Bed              2           1125
#
#            cancellation_policy         last_review  accommodates  bedrooms  \
# 0  strict_14_with_grace_period 2019-02-07 05:00:00             2       1.0
# 1  strict_14_with_grace_period 2018-08-12 04:00:00             2       1.0
# 2                     flexible                 NaT             4       1.0
# 3  strict_14_with_grace_period 2019-01-28 05:00:00             4       1.0
# 4                     flexible 2016-04-02 04:00:00             6       2.0
#
#    beds  number_of_reviews bathrooms   price cleaning_fee extra_people  \
# 0   1.0                 96       1.0  115.00       100.00         0.00
# 1   1.0                 70       1.0  135.00       135.00         0.00
# 2   2.0                  0       1.0   50.00          NaN        31.00
# 3   3.0                 70       2.0  119.00       150.00        40.00
# 4   6.0                  1       1.0  527.00       211.00       211.00
#
#   guests_included                                             images  \
# 0               1  https://a0.muscache.com/im/pictures/15037101/5...
# 1               1  https://a0.muscache.com/im/pictures/15074036/a...
# 2               1  https://a0.muscache.com/im/pictures/9fa69ad8-c...
# 3               3  https://a0.muscache.com/im/pictures/159d489e-6...
# 4               1  https://a0.muscache.com/im/pictures/231120b6-e...
#
#    review_scores  reviews_per_month
# 0             84                NaN
# 1             94                NaN
# 2              0                NaN
# 3             98                NaN
# 4            100                NaN

# %%
df_1
# Out:
#            _id                                            name property_type  \
# 0      1001265                Ocean View Waikiki Marina w/prkg   Condominium
# 1      1003530             New York City - Upper West Side Apt     Apartment
# 2     10057447                  Modern Spacious 1 Bedroom Loft     Apartment
# 3     10038496                    Copacabana Apartment Posto 6     Apartment
# 4     10047964                  Charming Flat in Downtown Moda         House
# ...        ...                                             ...           ...
# 5550   9639849               Well lit, quiet, modern apartment     Apartment
# 5551   9497614             Funky 1 Bed Apt - 10min walk to CBD     Apartment
# 5552   9765083                     House in a charming village         House
# 5553   9907907                      Large double room in Bondi     Apartment
# 5554   9990304  March Madness Special! Aina Nalu Platinum D107   Condominium
#
#             room_type  bed_type minimum_nights maximum_nights  \
# 0     Entire home/apt  Real Bed              3            365
# 1        Private room  Real Bed             12            360
# 2     Entire home/apt  Real Bed              1           1125
# 3     Entire home/apt  Real Bed              3             75
# 4     Entire home/apt  Real Bed              2           1125
# ...               ...       ...            ...            ...
# 5550     Private room  Real Bed              5             10
# 5551  Entire home/apt  Real Bed              6             31
# 5552     Private room  Real Bed              7           1125
# 5553     Private room  Real Bed              3           1125
# 5554  Entire home/apt  Real Bed              3            365
#
#               cancellation_policy         last_review  accommodates  bedrooms  \
# 0     strict_14_with_grace_period 2019-02-07 05:00:00             2       1.0
# 1     strict_14_with_grace_period 2018-08-12 04:00:00             2       1.0
# 2                        flexible                 NaT             4       1.0
# 3     strict_14_with_grace_period 2019-01-28 05:00:00             4       1.0
# 4                        flexible 2016-04-02 04:00:00             6       2.0
# ...                           ...                 ...           ...       ...
# 5550                     flexible 2017-01-07 05:00:00             2       1.0
# 5551  strict_14_with_grace_period                 NaT             2       1.0
# 5552                     flexible                 NaT             2       1.0
# 5553                     moderate                 NaT             2       1.0
# 5554  strict_14_with_grace_period 2018-08-06 04:00:00             6       2.0
#
#       beds  number_of_reviews bathrooms   price cleaning_fee extra_people  \
# 0      1.0                 96       1.0  115.00       100.00         0.00
# 1      1.0                 70       1.0  135.00       135.00         0.00
# 2      2.0                  0       1.0   50.00          NaN        31.00
# 3      3.0                 70       2.0  119.00       150.00        40.00
# 4      6.0                  1       1.0  527.00       211.00       211.00
# ...    ...                ...       ...     ...          ...          ...
# 5550   1.0                  1       1.5   65.00          NaN         0.00
# 5551   1.0                  0       1.0   74.00          NaN         0.00
# 5552   1.0                  0       1.0  351.00          NaN         0.00
# 5553   1.0                  0       1.0   60.00        50.00        50.00
# 5554   3.0                 13       2.0  227.00       289.00         0.00
#
#      guests_included                                             images  \
# 0                  1  https://a0.muscache.com/im/pictures/15037101/5...
# 1                  1  https://a0.muscache.com/im/pictures/15074036/a...
# 2                  1  https://a0.muscache.com/im/pictures/9fa69ad8-c...
# 3                  3  https://a0.muscache.com/im/pictures/159d489e-6...
# 4                  1  https://a0.muscache.com/im/pictures/231120b6-e...
# ...              ...                                                ...
# 5550               1  https://a0.muscache.com/im/pictures/8cc533db-a...
# 5551               1  https://a0.muscache.com/im/pictures/15f8aed7-b...
# 5552               1  https://a0.muscache.com/im/pictures/a51e6ddb-2...
# 5553               2  https://a0.muscache.com/im/pictures/17a8857a-6...
# 5554               1  https://a0.muscache.com/im/pictures/7d08e433-5...
#
#       review_scores  reviews_per_month
# 0                84                NaN
# 1                94                NaN
# 2                 0                NaN
# 3                98                NaN
# 4               100                NaN
# ...             ...                ...
# 5550            100                NaN
# 5551              0                NaN
# 5552              0                NaN
# 5553              0                NaN
# 5554             97                NaN
#
# [5555 rows x 21 columns]

# %%
df_1.isnull().sum()
# Out:
# _id                       0
# name                      0
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# last_review            1388
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# price                     0
# cleaning_fee           1531
# extra_people              0
# guests_included           0
# images                    0
# review_scores             0
# reviews_per_month      5461
# dtype: int64

# %%
df_1['bedrooms'].fillna(0, inplace=True)
df_1['beds'].fillna(0, inplace=True)
df_1['bathrooms'].fillna(0, inplace=True)
df_1['cleaning_fee'].fillna('Not Specified', inplace=True)
df_1.isnull().sum()
# Out:
# _id                       0
# name                      0
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# last_review            1388
# accommodates              0
# bedrooms                  0
# beds                      0
# number_of_reviews         0
# bathrooms                 0
# price                     0
# cleaning_fee              0
# extra_people              0
# guests_included           0
# images                    0
# review_scores             0
# reviews_per_month      5461
# dtype: int64

# %%
df_1.dtypes
# Out:
# _id                            object
# name                           object
# property_type                  object
# room_type                      object
# bed_type                       object
# minimum_nights                 object
# maximum_nights                 object
# cancellation_policy            object
# last_review            datetime64[ns]
# accommodates                    int64
# bedrooms                      float64
# beds                          float64
# number_of_reviews               int64
# bathrooms                      object
# price                          object
# cleaning_fee                   object
# extra_people                   object
# guests_included                object
# images                         object
# review_scores                   int64
# reviews_per_month             float64
# dtype: object

# %%
df_1['minimum_nights'] = df_1['minimum_nights'].astype(int)
df_1['maximum_nights'] = df_1['maximum_nights'].astype(int)
df_1['bedrooms'] = df_1['bedrooms'].astype(int)
df_1['beds'] = df_1['beds'].astype(int)
df_1['bathrooms'] = df_1['bathrooms'].astype(str).astype(float)
df_1['price'] = df_1['price'].astype(str).astype(float).astype(int)
df_1['cleaning_fee'] = df_1['cleaning_fee'].apply(lambda x: int(float(str(x))) if x != 'Not Specified' else 'Not Specified')
df_1['extra_people'] = df_1['extra_people'].astype(str).astype(float).astype(int)
df_1['guests_included'] = df_1['guests_included'].astype(str).astype(int)

# %%
df_1.dtypes
# Out:
# _id                            object
# name                           object
# property_type                  object
# room_type                      object
# bed_type                       object
# minimum_nights                  int64
# maximum_nights                  int64
# cancellation_policy            object
# last_review            datetime64[ns]
# accommodates                    int64
# bedrooms                        int64
# beds                            int64
# number_of_reviews               int64
# bathrooms                     float64
# price                           int64
# cleaning_fee                   object
# extra_people                    int64
# guests_included                 int64
# images                         object
# review_scores                   int64
# reviews_per_month             float64
# dtype: object

# %%
df_1.describe().T
# Out:
#                     count          mean           std  min   25%     50%  \
# minimum_nights     5555.0  5.564356e+00  2.261386e+01  1.0   1.0     2.0
# maximum_nights     5555.0  1.382776e+06  5.256920e+07  1.0  59.0  1125.0
# accommodates       5555.0  3.505851e+00  2.297019e+00  1.0   2.0     3.0
# bedrooms           5555.0  1.410441e+00  1.042334e+00  0.0   1.0     1.0
# beds               5555.0  2.066607e+00  1.620858e+00  0.0   1.0     2.0
# number_of_reviews  5555.0  2.760648e+01  4.979838e+01  0.0   1.0     5.0
# bathrooms          5555.0  1.288839e+00  7.037643e-01  0.0   1.0     1.0
# price              5555.0  2.787662e+02  8.422155e+02  9.0  70.0   129.0
# extra_people       5555.0  2.279190e+01  6.933151e+01  0.0   0.0     0.0
# guests_included    5555.0  1.747435e+00  1.487352e+00  1.0   1.0     1.0
# review_scores      5555.0  6.839568e+01  4.182983e+01  0.0   0.0    92.0
# reviews_per_month    94.0  1.712766e+00  1.492795e+00  1.0   1.0     1.0
#
#                       75%           max
# minimum_nights        3.0  1.250000e+03
# maximum_nights     1125.0  2.147484e+09
# accommodates          4.0  1.600000e+01
# bedrooms              2.0  2.000000e+01
# beds                  3.0  2.500000e+01
# number_of_reviews    32.0  5.330000e+02
# bathrooms             1.0  1.600000e+01
# price               280.0  4.884200e+04
# extra_people         20.0  2.346000e+03
# guests_included       2.0  1.600000e+01
# review_scores        98.0  1.000000e+02
# reviews_per_month     2.0  1.000000e+01

# %%
df_1.head(2)
# Out:
#        _id                                 name property_type  \
# 0  1001265     Ocean View Waikiki Marina w/prkg   Condominium
# 1  1003530  New York City - Upper West Side Apt     Apartment
#
#          room_type  bed_type  minimum_nights  maximum_nights  \
# 0  Entire home/apt  Real Bed               3             365
# 1     Private room  Real Bed              12             360
#
#            cancellation_policy         last_review  accommodates  bedrooms  \
# 0  strict_14_with_grace_period 2019-02-07 05:00:00             2         1
# 1  strict_14_with_grace_period 2018-08-12 04:00:00             2         1
#
#    beds  number_of_reviews  bathrooms  price cleaning_fee  extra_people  \
# 0     1                 96        1.0    115          100             0
# 1     1                 70        1.0    135          135             0
#
#    guests_included                                             images  \
# 0                1  https://a0.muscache.com/im/pictures/15037101/5...
# 1                1  https://a0.muscache.com/im/pictures/15074036/a...
#
#    review_scores  reviews_per_month
# 0             84                NaN
# 1             94                NaN

# %%
host = []
for i in col.find( {}, {'_id':1, 'host':1}):
    host.append(i)

# %%
df_host = pd.DataFrame(host)
host_keys = list(df_host.iloc[0,1].keys())
host_keys.remove('host_about')

# %%
for i in host_keys:
    if i == 'host_response_time':
        df_host['host_response_time'] = df_host['host'].apply(lambda x: x['host_response_time'] if 'host_response_time' in x else 'Not Specified')
    else:
        df_host[i] = df_host['host'].apply(lambda x: x[i] if i in x and x[i]!='' else 'Not Specified')

df_host.drop(columns=['host'], inplace=True)
df_host.head()
# Out:
#         _id   host_id                                    host_url  \
# 0   1001265   5448114   https://www.airbnb.com/users/show/5448114
# 1   1003530    454250    https://www.airbnb.com/users/show/454250
# 2  10057447  51612949  https://www.airbnb.com/users/show/51612949
# 3  10038496  51530266  https://www.airbnb.com/users/show/51530266
# 4  10047964   1241644   https://www.airbnb.com/users/show/1241644
#
#      host_name                                    host_location  \
# 0        David                  Honolulu, Hawaii, United States
# 1        Greta                New York, New York, United States
# 2   Konstantin                         Montreal, Quebec, Canada
# 3  Ana Valéria  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 4       Zeynep                       Istanbul, Istanbul, Turkey
#
#   host_response_time                                 host_thumbnail_url  \
# 0     within an hour  https://a0.muscache.com/im/users/5448114/profi...
# 1     within an hour  https://a0.muscache.com/im/pictures/f1022be4-e...
# 2      Not Specified  https://a0.muscache.com/im/pictures/beb6b50e-0...
# 3     within an hour  https://a0.muscache.com/im/pictures/8c7bb5fe-7...
# 4      Not Specified  https://a0.muscache.com/im/users/1241644/profi...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/5448114/profi...            Waikiki
# 1  https://a0.muscache.com/im/pictures/f1022be4-e...      Not Specified
# 2  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
# 3  https://a0.muscache.com/im/pictures/8c7bb5fe-7...         Copacabana
# 4  https://a0.muscache.com/im/users/1241644/profi...               Moda
#
#   host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0                 98              False                  True
# 1                100               True                  True
# 2      Not Specified              False                  True
# 3                100               True                  True
# 4      Not Specified              False                  True
#
#    host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                   False                   18                         18
# 1                    True                    3                          3
# 2                   False                    1                          1
# 3                    True                    2                          2
# 4                    True                    2                          2
#
#                                   host_verifications
# 0                       [email, phone, reviews, kba]
# 1  [email, phone, reviews, jumio, offline_governm...
# 2  [email, phone, jumio, offline_government_id, s...
# 3      [email, phone, reviews, jumio, government_id]
# 4  [email, phone, facebook, reviews, jumio, gover...

# %%
df_host['host_is_superhost'] = df_host['host_is_superhost'].map({False:'No',True:'Yes'})
df_host['host_has_profile_pic'] = df_host['host_has_profile_pic'].map({False:'No',True:'Yes'})
df_host['host_identity_verified'] = df_host['host_identity_verified'].map({False:'No',True:'Yes'})
df_host.head()
# Out:
#         _id   host_id                                    host_url  \
# 0   1001265   5448114   https://www.airbnb.com/users/show/5448114
# 1   1003530    454250    https://www.airbnb.com/users/show/454250
# 2  10057447  51612949  https://www.airbnb.com/users/show/51612949
# 3  10038496  51530266  https://www.airbnb.com/users/show/51530266
# 4  10047964   1241644   https://www.airbnb.com/users/show/1241644
#
#      host_name                                    host_location  \
# 0        David                  Honolulu, Hawaii, United States
# 1        Greta                New York, New York, United States
# 2   Konstantin                         Montreal, Quebec, Canada
# 3  Ana Valéria  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 4       Zeynep                       Istanbul, Istanbul, Turkey
#
#   host_response_time                                 host_thumbnail_url  \
# 0     within an hour  https://a0.muscache.com/im/users/5448114/profi...
# 1     within an hour  https://a0.muscache.com/im/pictures/f1022be4-e...
# 2      Not Specified  https://a0.muscache.com/im/pictures/beb6b50e-0...
# 3     within an hour  https://a0.muscache.com/im/pictures/8c7bb5fe-7...
# 4      Not Specified  https://a0.muscache.com/im/users/1241644/profi...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/5448114/profi...            Waikiki
# 1  https://a0.muscache.com/im/pictures/f1022be4-e...      Not Specified
# 2  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
# 3  https://a0.muscache.com/im/pictures/8c7bb5fe-7...         Copacabana
# 4  https://a0.muscache.com/im/users/1241644/profi...               Moda
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0                 98                No                  Yes
# 1                100               Yes                  Yes
# 2      Not Specified                No                  Yes
# 3                100               Yes                  Yes
# 4      Not Specified                No                  Yes
#
#   host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                     No                   18                         18
# 1                    Yes                    3                          3
# 2                     No                    1                          1
# 3                    Yes                    2                          2
# 4                    Yes                    2                          2
#
#                                   host_verifications
# 0                       [email, phone, reviews, kba]
# 1  [email, phone, reviews, jumio, offline_governm...
# 2  [email, phone, jumio, offline_government_id, s...
# 3      [email, phone, reviews, jumio, government_id]
# 4  [email, phone, facebook, reviews, jumio, gover...

# %%
df_host['host_is_superhost'] = df_host['host_is_superhost'].map({False:'No',True:'Yes'})
df_host['host_has_profile_pic'] = df_host['host_has_profile_pic'].map({False:'No',True:'Yes'})
df_host['host_identity_verified'] = df_host['host_identity_verified'].map({False:'No',True:'Yes'})
df_host.head()
# Out:
#         _id   host_id                                    host_url  \
# 0   1001265   5448114   https://www.airbnb.com/users/show/5448114
# 1   1003530    454250    https://www.airbnb.com/users/show/454250
# 2  10057447  51612949  https://www.airbnb.com/users/show/51612949
# 3  10038496  51530266  https://www.airbnb.com/users/show/51530266
# 4  10047964   1241644   https://www.airbnb.com/users/show/1241644
#
#      host_name                                    host_location  \
# 0        David                  Honolulu, Hawaii, United States
# 1        Greta                New York, New York, United States
# 2   Konstantin                         Montreal, Quebec, Canada
# 3  Ana Valéria  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 4       Zeynep                       Istanbul, Istanbul, Turkey
#
#   host_response_time                                 host_thumbnail_url  \
# 0     within an hour  https://a0.muscache.com/im/users/5448114/profi...
# 1     within an hour  https://a0.muscache.com/im/pictures/f1022be4-e...
# 2      Not Specified  https://a0.muscache.com/im/pictures/beb6b50e-0...
# 3     within an hour  https://a0.muscache.com/im/pictures/8c7bb5fe-7...
# 4      Not Specified  https://a0.muscache.com/im/users/1241644/profi...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/5448114/profi...            Waikiki
# 1  https://a0.muscache.com/im/pictures/f1022be4-e...      Not Specified
# 2  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
# 3  https://a0.muscache.com/im/pictures/8c7bb5fe-7...         Copacabana
# 4  https://a0.muscache.com/im/users/1241644/profi...               Moda
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0                 98               NaN                  NaN
# 1                100               NaN                  NaN
# 2      Not Specified               NaN                  NaN
# 3                100               NaN                  NaN
# 4      Not Specified               NaN                  NaN
#
#   host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    NaN                   18                         18
# 1                    NaN                    3                          3
# 2                    NaN                    1                          1
# 3                    NaN                    2                          2
# 4                    NaN                    2                          2
#
#                                   host_verifications
# 0                       [email, phone, reviews, kba]
# 1  [email, phone, reviews, jumio, offline_governm...
# 2  [email, phone, jumio, offline_government_id, s...
# 3      [email, phone, reviews, jumio, government_id]
# 4  [email, phone, facebook, reviews, jumio, gover...

# %%
df_host.dtypes
# Out:
# _id                          object
# host_id                      object
# host_url                     object
# host_name                    object
# host_location                object
# host_response_time           object
# host_thumbnail_url           object
# host_picture_url             object
# host_neighbourhood           object
# host_response_rate           object
# host_is_superhost            object
# host_has_profile_pic         object
# host_identity_verified       object
# host_listings_count           int64
# host_total_listings_count     int64
# host_verifications           object
# dtype: object

# %%
address = []
for i in col.find( {}, {'_id':1, 'address':1}):
    address.append(i)

df_address = pd.DataFrame(address)
address_keys = list(df_address.iloc[0,1].keys())

# %%
for i in address_keys:
    if i == 'location':
        df_address['location_type'] = df_address['address'].apply(lambda x: x['location']['type'])
        df_address['longitude'] = df_address['address'].apply(lambda x: x['location']['coordinates'][0])
        df_address['latitude'] = df_address['address'].apply(lambda x: x['location']['coordinates'][1])
        df_address['is_location_exact'] = df_address['address'].apply(lambda x: x['location']['is_location_exact'])
    else:
        df_address[i] = df_address['address'].apply(lambda x: x[i] if x[i]!='' else 'Not Specified')

df_address.drop(columns=['address'], inplace=True)
df_address.head()
# Out:
#         _id                                  street      suburb  \
# 0   1001265             Honolulu, HI, United States       Oʻahu
# 1   1003530             New York, NY, United States   Manhattan
# 2  10057447                Montréal, Québec, Canada    Mile End
# 3  10038496  Rio de Janeiro, Rio de Janeiro, Brazil  Copacabana
# 4  10047964               Kadıköy, İstanbul, Turkey        Moda
#
#          government_area          market        country country_code  \
# 0   Primary Urban Center            Oahu  United States           US
# 1        Upper West Side        New York  United States           US
# 2  Le Plateau-Mont-Royal        Montreal         Canada           CA
# 3             Copacabana  Rio De Janeiro         Brazil           BR
# 4                Kadikoy        Istanbul         Turkey           TR
#
#   location_type   longitude   latitude  is_location_exact
# 0         Point -157.839190  21.286340               True
# 1         Point  -73.965230  40.799620              False
# 2         Point  -73.591110  45.518890               True
# 3         Point  -43.190849 -22.984339              False
# 4         Point   29.031330  40.985850               True

# %%
df_address['is_location_exact'] = df_address['is_location_exact'].map({False:'No',True:'Yes'})
df_address.head()
# Out:
#         _id                                  street      suburb  \
# 0   1001265             Honolulu, HI, United States       Oʻahu
# 1   1003530             New York, NY, United States   Manhattan
# 2  10057447                Montréal, Québec, Canada    Mile End
# 3  10038496  Rio de Janeiro, Rio de Janeiro, Brazil  Copacabana
# 4  10047964               Kadıköy, İstanbul, Turkey        Moda
#
#          government_area          market        country country_code  \
# 0   Primary Urban Center            Oahu  United States           US
# 1        Upper West Side        New York  United States           US
# 2  Le Plateau-Mont-Royal        Montreal         Canada           CA
# 3             Copacabana  Rio De Janeiro         Brazil           BR
# 4                Kadikoy        Istanbul         Turkey           TR
#
#   location_type   longitude   latitude is_location_exact
# 0         Point -157.839190  21.286340               Yes
# 1         Point  -73.965230  40.799620                No
# 2         Point  -73.591110  45.518890               Yes
# 3         Point  -43.190849 -22.984339                No
# 4         Point   29.031330  40.985850               Yes

# %%
df_address.isnull().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %%
df_address.dtypes
# Out:
# _id                   object
# street                object
# suburb                object
# government_area       object
# market                object
# country               object
# country_code          object
# location_type         object
# longitude            float64
# latitude             float64
# is_location_exact     object
# dtype: object

# %%
availability = []
for i in col.find( {}, {'_id':1, 'availability':1}):
    availability.append(i)

df_availability = pd.DataFrame(availability)
availability_keys = list(df_availability.iloc[0,1].keys())

# %%
for i in availability_keys:
    df_availability['availability_30'] = df_availability['availability'].apply(lambda x: x['availability_30'])
    df_availability['availability_60'] = df_availability['availability'].apply(lambda x: x['availability_60'])
    df_availability['availability_90'] = df_availability['availability'].apply(lambda x: x['availability_90'])
    df_availability['availability_365'] = df_availability['availability'].apply(lambda x: x['availability_365'])

df_availability.drop(columns=['availability'], inplace=True)
df_availability.head()
# Out:
#         _id  availability_30  availability_60  availability_90  \
# 0   1001265               16               46               76
# 1   1003530                0                0                0
# 2  10057447                0                0                0
# 3  10038496                7               19               33
# 4  10047964               27               57               87
#
#    availability_365
# 0               343
# 1                93
# 2                 0
# 3               118
# 4               362

# %%
df_availability.isnull().sum()
# Out:
# _id                 0
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
df_availability.dtypes
# Out:
# _id                 object
# availability_30      int64
# availability_60      int64
# availability_90      int64
# availability_365     int64
# dtype: object

# %%
def amenities_sort(x):
    a = x
    a.sort(reverse=False)
    return a

amenities = []
for i in col.find( {}, {'_id':1, 'amenities':1}):
    amenities.append(i)

df_amenities = pd.DataFrame(amenities)
df_amenities['amenities'] = df_amenities['amenities'].apply(lambda x: amenities_sort(x))
df_amenities.head()
# Out:
#         _id                                          amenities
# 0   1001265  [Air conditioning, BBQ grill, Bed linens, Cabl...
# 1   1003530  [Air conditioning, Buzzer/wireless intercom, D...
# 2  10057447  [24-hour check-in, Dryer, Essentials, Family/k...
# 3  10038496  [Air conditioning, Bed linens, Buzzer/wireless...
# 4  10047964  [24-hour check-in, Cable TV, Cat(s), Essential...

# %%
df_amenities.isnull().sum()
# Out:
# _id          0
# amenities    0
# dtype: int64

# %%
df_amenities.dtypes
# Out:
# _id          object
# amenities    object
# dtype: object

# %%
df = pd.merge(df_1, df_host, on='_id')
df = pd.merge(df, df_address, on='_id')
df = pd.merge(df, df_availability, on='_id')
df = pd.merge(df, df_amenities, on='_id')
df.head(3)
# Out:
#         _id                                 name property_type  \
# 0   1001265     Ocean View Waikiki Marina w/prkg   Condominium
# 1   1003530  New York City - Upper West Side Apt     Apartment
# 2  10057447       Modern Spacious 1 Bedroom Loft     Apartment
#
#          room_type  bed_type  minimum_nights  maximum_nights  \
# 0  Entire home/apt  Real Bed               3             365
# 1     Private room  Real Bed              12             360
# 2  Entire home/apt  Real Bed               1            1125
#
#            cancellation_policy         last_review  accommodates  bedrooms  \
# 0  strict_14_with_grace_period 2019-02-07 05:00:00             2         1
# 1  strict_14_with_grace_period 2018-08-12 04:00:00             2         1
# 2                     flexible                 NaT             4         1
#
#    beds  number_of_reviews  bathrooms  price   cleaning_fee  extra_people  \
# 0     1                 96        1.0    115            100             0
# 1     1                 70        1.0    135            135             0
# 2     2                  0        1.0     50  Not Specified            31
#
#    guests_included                                             images  \
# 0                1  https://a0.muscache.com/im/pictures/15037101/5...
# 1                1  https://a0.muscache.com/im/pictures/15074036/a...
# 2                1  https://a0.muscache.com/im/pictures/9fa69ad8-c...
#
#    review_scores  reviews_per_month   host_id  \
# 0             84                NaN   5448114
# 1             94                NaN    454250
# 2              0                NaN  51612949
#
#                                      host_url   host_name  \
# 0   https://www.airbnb.com/users/show/5448114       David
# 1    https://www.airbnb.com/users/show/454250       Greta
# 2  https://www.airbnb.com/users/show/51612949  Konstantin
#
#                        host_location host_response_time  \
# 0    Honolulu, Hawaii, United States     within an hour
# 1  New York, New York, United States     within an hour
# 2           Montreal, Quebec, Canada      Not Specified
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/5448114/profi...
# 1  https://a0.muscache.com/im/pictures/f1022be4-e...
# 2  https://a0.muscache.com/im/pictures/beb6b50e-0...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/5448114/profi...            Waikiki
# 1  https://a0.muscache.com/im/pictures/f1022be4-e...      Not Specified
# 2  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0                 98               NaN                  NaN
# 1                100               NaN                  NaN
# 2      Not Specified               NaN                  NaN
#
#   host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    NaN                   18                         18
# 1                    NaN                    3                          3
# 2                    NaN                    1                          1
#
#                                   host_verifications  \
# 0                       [email, phone, reviews, kba]
# 1  [email, phone, reviews, jumio, offline_governm...
# 2  [email, phone, jumio, offline_government_id, s...
#
#                         street     suburb        government_area    market  \
# 0  Honolulu, HI, United States      Oʻahu   Primary Urban Center      Oahu
# 1  New York, NY, United States  Manhattan        Upper West Side  New York
# 2     Montréal, Québec, Canada   Mile End  Le Plateau-Mont-Royal  Montreal
#
#          country country_code location_type  longitude  latitude  \
# 0  United States           US         Point -157.83919  21.28634
# 1  United States           US         Point  -73.96523  40.79962
# 2         Canada           CA         Point  -73.59111  45.51889
#
#   is_location_exact  availability_30  availability_60  availability_90  \
# 0               Yes               16               46               76
# 1                No                0                0                0
# 2               Yes                0                0                0
#
#    availability_365                                          amenities
# 0               343  [Air conditioning, BBQ grill, Bed linens, Cabl...
# 1                93  [Air conditioning, Buzzer/wireless intercom, D...
# 2                 0  [24-hour check-in, Dryer, Essentials, Family/k...

# %%
df.dtypes
# Out:
# _id                                  object
# name                                 object
# property_type                        object
# room_type                            object
# bed_type                             object
# minimum_nights                        int64
# maximum_nights                        int64
# cancellation_policy                  object
# last_review                  datetime64[ns]
# accommodates                          int64
# bedrooms                              int64
# beds                                  int64
# number_of_reviews                     int64
# bathrooms                           float64
# price                                 int64
# cleaning_fee                         object
# extra_people                          int64
# guests_included                       int64
# images                               object
# review_scores                         int64
# reviews_per_month                   float64
# host_id                              object
# host_url                             object
# host_name                            object
# host_location                        object
# host_response_time                   object
# host_thumbnail_url                   object
# host_picture_url                     object
# host_neighbourhood                   object
# host_response_rate                   object
# host_is_superhost                    object
# host_has_profile_pic                 object
# host_identity_verified               object
# host_listings_count                   int64
# host_total_listings_count             int64
# host_verifications                   object
# street                               object
# suburb                               object
# government_area                      object
# market                               object
# country                              object
# country_code                         object
# location_type                        object
# longitude                           float64
# latitude                            float64
# is_location_exact                    object
# availability_30                       int64
# availability_60                       int64
# availability_90                       int64
# availability_365                      int64
# amenities                            object
# dtype: object

# %%
# download as csv file from mongodb
df.to_csv('airbnb.csv', index=False)
